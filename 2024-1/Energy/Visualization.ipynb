# %% [markdown]
# Python, Introduce
# ===
# Visualization, Advanced
# ===
#
# ```
#   Data In, Data Out      ⇔    Garbage In, Garbage Out?
#   Data In, Garbage Out        Garbage In, Data Out
#         Medusa           or         Midas
# ```
# **Lecture Objectives**<br>
#
# ```
# Get the Data and Utilize with Them
# ```
# 1. Where Data Comes from? (Data Scraping)
# 2. Visualization, from Fundamental to Sophiscated,<br>
# <font face="Georgia, time" color="brown"> Matlibplot/seaborn +  Plotly, pyecharts,<br> Static ➠ Animation</font>
# 3. Story Teller, Fortune Teller,
#
#
#
#
# <big>
#
# 1. Lecturer: CCH, Time: AM 8:00-11:00, xxxx/xx/xx
# 2. [Code on github](), [Lecture]()

# %%
# display Google Image
from IPython.display import Image

# %%
# mount Google drive and this folder
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
dir= '/content/drive/MyDrive/2023/CGU'

# %% [markdown]
# **Example.** How and What the Climate Change of Earth, [code]()
#
# ---
#
# [Climate data]()
# ```
# Database: US NOAA
# Data: annual Global Climate change,
# ```
# Description
# ---
# Create Animation based on Annual Temperature changes
#
#
# Review:
# ```
#  Animation = Playing a sequence of ordered pictue
#  ```

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em"> Make Animation</font>
#   </a>
#
# Create Global's pic, Append one by one and by years:
# </summary>
#
# <big>
#
# ```python
# images = []
# i=1
# for year in df.columns[1:]:
#     ### generate PNG's
#     merged = world.merge(...)
#     fig, ax = plt.subplots(...)
#     merged.plot(...)
#     ...
#     ### Save the map as an image file
#     filename = f'./images/{year}.png'
#     plt.savefig(filename, dpi=300)
#     images.append(imageio.imread(filename))
#     plt.close()
#     i+=1
# ```
# </details>

# %%
Image(dir+"/gif/temperature_change_FINAL.gif")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Conclusion
#  ---
#
#  ```
#  Climate Change is Messing with the time greater than previous thought
#
# ```
#
# Note
# ---
# Color "red"!

# %% [markdown]
# Where the Data come
# ---
# 1. Scrape the data, from internet, by [BeautifulSoup]()
# 2. <font color="grey">use LLM, Large Language Model</font>, [claude](), or [groq](),...

# %% [markdown]
# <big>
#
# What is <font color="brown">`Scrape`</font>
# ---
#
# ```
# from Proto-Germanic: skrapōną, skrepaną (“to scrape, scratch”),
# ```
# means to remove an unwanted covering or a top layer from something. <br>
# **Nowaday**, <br>
#
#   <font size=+1>Scrape data ➠. Retrieving the data from web</font>.

# %% [markdown]
# [link text](https://) **bs4**, Python Package
#
# the simplest way to get data from the web.
#
# **Useage**, [code](), automatically `duplicate` the value in object (web source) and ...

# %% [markdown]
# **Example**, <br>Global's Temperature varied since last decade , Last Century
# ---
# 1. Scrape [Data](), annual gloabal Temp changes.
# 2.Visualization, bar plot (matplotlib), with <font color="brown">certain effects</font>, [lecture code]():

# %%
# !ls images
# Out:
# ls: cannot access 'images': No such file or directory

# %%
Image(dir+"/images/Tempchang.png")

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em">Data Scraping</font>
#   </a>
#
# **Reference** [LLM, Groq](...), (below)<br>
# Explore the `<table id="...">` ➡︎ `<th>` ➡︎  `<tr>` then the values of `<td>`
# </summary>
#
# ```python
# ...
# # Parse the HTML content
# soup = BeautifulSoup(html_content, 'html.parser')
#
# # Find the table
# table = soup.find('table', {'id': 'tablepress-4149'})
#
# if table:
#     # Extract the table headers
#     headers = [th.text.strip() for th in table.find_all('th')]
#
#     # Extract the table data
#     data = []
#     for row in table.find_all('tr')[1:]:
#         row_data = [td.text.strip() for td in row.find_all('td')]
#         data.append(row_data)
# ```
# </details>

# %% [markdown]
# <big>**Bonus**,</big>
# 1. Watch the page source,
# 2. use LLM  with the propmt:
# ```
# Use bs4 to get the data from ..., and load into DataFrame
# ```
# Et voilà.

# %% [markdown]
# **Bar**
#
# ```python
# ...
# sns.barplot(data=temp_df,...)
# ...
# ```

# %%
Image(dir+"/images/bar.png")

# %% [markdown]
# Question
# ---
# What does the color (bar) mean?

# %% [markdown]
# <big><font color="red">Important:</font></big> <br>
# What should we do if the content was not analyzed, due to generated by (well-protested) javascript?

# %% [markdown]
# **Another Factor**, Oil comsumption
#
# ```
# Oil comsumption  ➡︎  CO2  ➡︎  Global Temperture arises!
# ```
#
# Get data from [OIl Consumption](...) and visualize together with above data, [src]()

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em">Multiple Charts</font>
#   </a>
#
# *y*-Axes shared
# </summary>
#
# ```python
# fig, ax1 = plt.subplots(figsize=(12, 4))
# ...
# sns.lineplot...)
# ...
# ax2 = ax1.twinx()
# ax2=sns.barplot(...)
# ...
# ```
# </details>

# %%
# matplotlib styple, y-axes shared

Image(dir+"/images/oilTemp-matplotlib.png",width=600)

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em">Plotly</font>
#   </a>
#
# Interactvity available
# </summary>
#
# ```python
# from plotly.subplots import make_subplots
#
# fig = make_subplots(specs=[[{"secondary_y": True}]])
# fig.add_trace(go.Scatter(x=lx, y=temp_df['Oil (TWh growth)'], mode='lines+markers',...,
#     secondary_y=False,)
# fig.add_trace(go.Bar(x=lx, y=temp_df['change'],  ..., secondary_y=True)
# ...
# ```
# </details>

# %%
# plotly style, more feature, interactivity
Image(dir+"/images/oilTemp.png")

# %% [markdown]
# Pros
# ---
# 1. convince someone of
# ```
# The more Oil Consumption, the Worse the Global Temperature
# ```
# 2. plotly: flexibly and beautifully
#
# Cons
# ---
# 1. plotly is much complicated and Memory Monster.

# %% [markdown]
# **Soft Skill but Fundamental**, Carmine  Gallo, MIT:
# ```
#     In the age of AI, like the ability to
#        claritfy, persuade, modivate, and inspire
#     are more valuable than ever.
#
# ```

# %% [markdown]
# Example, Which is the Worst Country
# ---
# Use [Data]() to Analyze the Electricity Comsumption of Countries.
#
#
#
#
# Additional objective of this examlple:
# ```
# Become a successful Lobbyist,
# ```
# for example: Su-Chin, 蘇秦, the prime minister of six countries in Ancient Dynasty Chou against Chin.

# %% [markdown]
# <Big>
# Continued,
#
# ```
#  CO2 ➚  ➠ Temperature ➚
#  ```

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em">Pie Chart</font>
#   </a>
#
# pyecharts, OO-styled
# </summary>
#
# ```python
# from pyecharts.charts import Pie
#
# c1 = (
#       Pie()
#       .add("CO2 Emitting",dataset1,
#          radius=["45%", "75%"],
#          center=["45%", "50%"],
#          rosetype="radius",
#         )
#     ...
# )
# ```
# </details>

# %%
# International Electricity Comsumption, 2022
# pyechart, interactivity
Image(dir+"/images/pie.png")

# %% [markdown]
# Note
# ---
# 1. To imporove output quality, use `pyecharts` package, and in Rose style:
# - Rose style, the data displayed according to quantity, `width of sector`;
# - Clockwisely descend the data

# %% [markdown]
# Example, Continued
# ---
# <big>
#    &nbsp; &nbsp; &nbsp; &nbsp;
#    Power plants <Big> ➠ </Big> Electricity power + <font color="brown">CO2</font>.
#
# ```
# Which country exhausted Electricity mostly?
# ```

# %% [markdown]
# 1. Download historic [data](), data of Electricity Consumption.
# 2. Download data of population size from [Wikimedia]()
# 3. Data Visulise
#    - Total Electricity Consumption,
#    - Electricity Consumption in person.
#           Total E Com/Population Size

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em">Bar Chart</font>
#   </a>
#
# pyecharts, Multiple Bars
# </summary>
#
# ```python
# from pyecharts.charts import Bar
#
# c1 = (
#       Bar()
#       # labels in X axis
#       .add_xaxis(countries)
#       # first bar plot
#       .add_yaxis(TotalComp)
#       # second bar plot
#       .add_yaxis(AvgEComp)
#     ...
# )
# ```
# </details>

# %%
Image(dir+"/images/Power.png")

# %% [markdown]
# Summary
# ---
# 1. China is the
# The main culprit of `Power Consumption` in the world.
# 2. <font color="brown">Taiwan is Top 11 power comsumption (in person) </font>
#
# **Discussion**, <br>
# What do you think:
#
# ```
# Jenson Huang, CEO of Nvidia:
#
#    Invest Taiwan `More`, including building Large DATA research/storage center.
# ```
#
# Also Amazon had acclaimed simliar investment project in Taiwan at June, 2024.
#
#
# Such issues requires more power supply; these make "power outage" more seriously.

# %% [markdown]
# Summary
# ---
# What you had in this talk:
#
# 1. skill of `data scraping`,  LLM, bs4, and we...
# 2. (Geo-)Animation
# 3. Diverse Visualization, matplotlib, plotly, pyecharts, <br>(Rose-style Pie, Multiple histogram, interactivity capacity.)
# 4. Story/Fortune Teller (with pics)

# %% [markdown]
# Group Report, (10%) (Deadline before next Sunday, xxxx/xx/xx)
# ---
# **Who is Worse in `CO2 generated` policy? China or Taiwan?**<br> Explain your reason with  evidence, and upload your discussion/result,<br> only <font color="red">`pdf`</font> format accepted.
#
# Welcome anyone to discuss respectively and post individual suggestion or comment if any.<br> `Additional` score gains for good options.
#
# **Group homework**,
# 1. self-grouped but not more than 10 persons, (Total 80 persons)
#
# <font color="red">`DOES NOT`</font> attend same group with your best friend, otherwise, you would feel very sorry if any conflict occurs.
