# %% [markdown]
# 氣候變遷，電力篇
# ===
# Energy Resources and Sustainable Civilization
# ===
# Electricity Power
# ---
# **Date, 2024/11/7**
#
#
# <Big><Big>
# <img src="https://drive.google.com/uc?export=view&id=1owU0QW97LdvV8lgORnMycFmyRgOIdTO9" width=1000 />
#
#
# <img src="https://drive.google.com/uc?export=view&id=1ogyG9W9nXz5r37GFrB3v66E_B9K4ufOg" width=1000 />

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em"><font color="brown">課程目標</font></font>
#   </a>
#
#   <Big><Big>
#     1. 全球電力供應。<br>
#     2. 各種發電方式的優缺點及對環境的影響。<br>
#     3. 各國電力消費量比較。<br>
#     4. 反思個人如何節能減碳。<br>
#   </Big> </Big>
# <br>
#
#
# </summary>
# </details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em"><font color="brown">一、電力與現代生活</font></font>
#   </a>
#
#   <Big><Big>
#     1. 電力在現代生活中的重要性。<br>
#     2. 電力需求不斷成長的原因。<br>
#     3. 電力短缺可能帶來的影響。<br>
#   </Big> </Big>
# <br>
#
# </summary>
#
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em"><font color="brown">1. 電力在現代生活中的重要性。</font></font>
#   </a>
#
#   <Big><Big>
#     生活, 生產，科技， 交通，生活品質
#
#   <img src="https://drive.google.com/uc?export=view&id=1PiQFNvyOxp1TJtxdP04N7fYN83jnICSN" width=600 />
#
# ---
# </summary>
#
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em"><font color="brown">2. 電力需求不斷成長的原因<br></font></font>
#   </a>
#
#   <Big><Big>
#     人口，經濟，生活，科技， 氣候變遷
#
#
# <img src="https://drive.google.com/uc?export=view&id=1NnFQKORBxmzERGr-r66k3OlODeCPuvJq" width=600 />
#
#
#  ---
#
# </summary>
#
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em"><font color="brown">3. 電力短缺可能帶來的影響。<<br></font></font>
#   </a>
#
#   <Big><Big>
#     生產停滯， 生活不變， 基礎設施， 環境污染，經濟損失
#
#
#  <img src="https://drive.google.com/uc?export=view&id=1-NoeNynJlbfXgfAslOJE78_HF-TUSn6d" width=600 />
#
#  ---
#
# </summary>
#
# <details>
# <summary>
#
#   <Big><Big>
# 總決
#
#  <img src="https://drive.google.com/uc?export=view&id=1MicrBzMikpoRY63do4_u5B59thXeHJ_8" width=600 />
#
#
#
# </details></details></details></details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em"><font color="brown">二、全球電力供應現況 </font></font>
#   </a>
#
# </summary>
# <details>
# <summary>
#
# <Big><Big>
#  電力來源比例, (台灣2023)
#  ===
#  經濟部 (2004a)
#  ---
#
#  <Big><Big>
#  2023年全國總發電量為2821.36億度<br>
# <Big>
# 1, 燃氣（39.57%）、再生能源（9.47%）、核能（6.31%）、燃油（1.34%）、抽蓄水力（1.08%）<br>
# 2, 2020, 政府承諾 2025 綠電占比要 20%，現在只有 <font color="red">7.8%</font>，2024 行政院長 2030 年要到 30%。<br>
# 3, 2024,10月31日, 康芮颱風襲台, 火力發電達 <font color="red">94.452%</font>!
#
# <Big>
# Note: 颱風夜要做什麼? 到小巨蛋, 只為省電, JaJ.
#
# ---
# </summary>
# <details>
# <summary>
#
#   <Big><Big>
# 各類能源的發電原理簡述。
# ===
#
# 火力 發電
# ---
# <Big><Big>
# <font color="brown">
# 蒸氣蒸氣機 <big>➠</big> 轉動 <big>➠</big> 發電機
# </font>
#
# 水利 發電
# ---
# <img src="https://drive.google.com/uc?export=view&id=1f8zzfK_C9BiFsj0KudM7V8zW8m5oSXNb" width=500 />
#
# 太陽能發電
# ---
# <img src="https://drive.google.com/uc?export=view&id=1ZCRdcpMTICyTsdUFfLItClwREkKCGEu9"  />
#
# </summary>
# <details>
# <summary>
#
# 各國電力消費量比較
# ===
#
# <Big>
# 1. 世界前幾大用電國<Br>
# <img src="https://drive.google.com/uc?export=view&id=1nU-skfaS3OZzo68oYEmhe6-G1zybPkkc" width=600 />
#
#
# ---
#
# </summary>
# <details>
# <summary>
#
#
#
#
# 電力產業的挑戰：
# ===
#
# <Big>
# 1. 穩定供電與環境保護的平衡<br>
# 2. 能源轉型面臨的困難。
#
# </summary>
# </details></details></details></details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em"><font color="brown">三、各種發電方式的優缺點 </font></font>
#   </a>
#
# </summary>
# <details>
# <summary>
#
#
# 傳統化石燃料發電：
# ---
#
# <Big></Big>
#  - 優點：技術成熟、成本較低。
#  - 缺點：造成空氣污染、溫室氣體排放。
#
# 1952, 倫敦大霧, 超過五千人死亡
#
# <img src="https://drive.google.com/uc?export=view&id=1mdurMZ6tVifN4P7Q2wfqXCVCiQaeqOFc" width=600 />
#
#  ---
#
# </summary>
# <details>
# <summary>
#
#
# 核能發電：
# ---
#
# <Big></Big>
#  - 優點：發電量大、碳排放低。
#  - 缺點：核廢料處理、核災風險。
#
# 日本 福島核電廠
#
# <img src="https://drive.google.com/uc?export=view&id=1pWd4vPmmGvaVy2k16OaEqlIpIsIv9vlN" width=600 />
#
#
#
#  ---
#
#  </summary>
# <details>
# <summary>
#
#
# 水力發電：
# ---
#
# <Big></Big>
#
#  - 優點：可再生能源、無污染。
# <img src="https://drive.google.com/uc?export=view&id=1PrWmvxPQrKy5itrkrWTSeztPEDAntrIl" width=600 />
#
#  - 缺點：對生態環境的影響。
#
#  <img src="https://drive.google.com/uc?export=view&id=1qFMrCLNoqpkTUukdM1jSDl1sNNA-lmu-" width=600 />
#
#
#  ---
#
#  </summary>
# <details>
# <summary>
#
#
# 再生能源發電
# ---
#
# <Big></Big>
#
#  - 優點：清潔能源、可再生。
#  - 缺點：受天候影響、初期投資成本高。
#
#   <img src="https://drive.google.com/uc?export=view&id=1RrxZGhsLlJzYPf1L0suw25_BHIhUOo5r" width=600 />
#
# ===
#  </details> </details> </details> </details> </details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em"><font color="brown">四、節能減碳的重要性與行動 </font></font>
#   </a>
#
# </summary>
# <details>
# <summary>
#
# 節能減碳對抗氣候變遷的重要性。
# ---
#
#
# ---
#
# </summary>
# <details>
# <summary>
#
# 節能減碳行動
# ---
#
# <Big></Big>
#  - 日常生活中的節電方法: 隨手關燈, 拔除待機電源, 整冷氣溫度, ...
#  - 選擇綠色能源: 使用再生能源, 選購節能產品
#  - 支持再生能源發展: 減少碳足跡, 支持相關政策
#
# ===
#
# </summary>
# </details></details></details></details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="6em"><font color="brown"> 小道消息 </font></font>
#   </a>
#
# </summary>
# <details>
# <summary>
#
# <Big></Big>
# 1. 保證供綠電 100 億度
# 2. 向菲律賓買電，一度四塊錢，台灣七塊錢
# 3. <font color="red">SMR ( 小型核力發電 )</font>
#
# ---
#
# </summary>
#
# <details>
# <summary>
#
#
# 小型核力發電, Small Modular Reactor, SMR)
# ---
#
# <Big></Big>
# 特點
#
# 1. 電力輸出 < 300MW
# 2. 結構模組化
# 3. 冷卻方式可 水冷， 氣冷
#
# ---
# </summary>
# <details>
# <summary>
#
#
# 小型核力發電, Small Modular Reactor, SMR)
# ---
#
# <Big></Big>
# 缺點
#
# 1. 興建時間長
# 2. 廢料更多<br>
#    <pre> Lindsay M. Krall et.al.,  Nuclear waste from small modular, reactors, May 31, 2022, PANS</pre>
# 3. 使用低濃度燃料棒， 來源少不能自主
#
# ---
# </summary>
# <details>
# <summary>
#
# <Big></Big>
# OKOL (OKOL yahoo, OpenAI), SMR (SMR yahoo, Nuscale)
#
# </summary>
#
#
#
# </details></details></details>
