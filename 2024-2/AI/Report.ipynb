# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown"> AI's Lecture, Report</font></font>
#   </a>
#  <br>
# <big>
#
# <big>
# <b>Abstract </b><p>
# </big>
#
# <big>
# This report analyzes historical grocery transaction data to support strategic decisions for inventory stocking and sales optimization. Here, we use AI and data science techniques, learned in this lecture, including
#
# <ol>
#   <li> Discovered high-frequency item combinations (market basket analysis)
#   <li> Predicted weekly demand for popular items
#   <li> Proposed a data-driven stocking strategy
# </ol>
#
# Finally, the analysis focuses on maximizing revenue through intelligent restocking and identifying synergistic product pairings.
# </big>
# </summary>
#
# </details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown"> Introduction</font></font>
#   </a>
#  <br>
# <big>
#
# <big>
# <b>Dataset </b><p>
# </big>
#
# <big>
#
#
# <ol>
#   <li> Source: 2014–2015 grocery transaction records,
#   <li> Features include:
#        <pre>Date, Item, Order ID, Weekday</pre>
#   <li> Objective: uncover patterns and forecast future demand for popular items
# </ol>
#
# </big>
# </summary>
#
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown"> EDA/DataWashing</font></font>
#   </a>
#  <br>
# <ol>
#   <li> Format Convertion, DateTime data (Year,  Month, Week, Day, Weekday)
#   <li> Visualization analysis, (Trend, seasoning,...)
#   <li> Purchased Analysis, (Wordcloud, TreeMapp)<br>
#   <img src="https://drive.google.com/uc?export=view&id=17I-FRta0X1a9e_78UgPxUiD1oAB4A3Ds"  width=400 />
# </ol>
#
#
# <big>
#
#
#
# </details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown"> Market Basket Analysis</font></font>
#   </a>
#  <br>
# <big>
#
#
# <big>
# Using the Apriori algorithm, <b>mxltend</b> package, to identify:
#
# <ol>
#   <li> Discovered high-frequency item combinations (market basket analysis)
#   <li> Predicted weekly demand for popular items
#   <li> Proposed a data-driven stocking strategy
# </ol>
#
# </big>
# </summary>
#
#
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown"> Key Association Insights</font></font>
#   </a>
#  <br>
# <big>
#
# <ol>
#   <li>🥛 Whole milk is the most central product in baskets
#   <li>🥖 Frequently paired with: bread, yogurt, rolls
#   <li>🛍️ Consider bundling offers or adjacent shelving<ol>
#
# </summary>
# <details>
# <summary>
# Example Rules (Top Lift > 2):
# </summary>
#
# <big><big>
# <table>
# <tr><th> Antecedents </th><th> Consequents </th><th> Lift </th></tr>
# <tr><td> {whole milk} </td><td> {bread}    </td><td> 2.4  </td></tr>
# <tr><td> {yogurt} </td><td>    {whole milk}</td><td> 2.2 </td></tr>
# </table>
# </summary>
#
#
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown"> Visualization of Associate Rule </font></font>
#   </a>
# <br>
# <b>Parallel Category Plot </b><p>
# </big>
#
# <img src="https://drive.google.com/uc?export=view&id=1dmlsC1G7o_W2EoWb_YYKZ57W9_arqiIf" width=600 />
#
# </details>
# </details>
# </details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown"> Application 1</font></font>
#   </a>
#  <br>
# <big>
# <br>
# <b>Weekly Sales Forecasting</b></br>
#
# By Meta's Prophet package:
# <ol>
#   <li>Aggregated weekly sales per item
#   <li>Used regression to forecast next month's demand
#   <li> Example: Predicting sales for whole milk<br>
# </ol>
# </summary>
# </details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown"> Application 2</font></font>
#   </a>
#  <br>
# <big>
# <br>
# <b>Proposed Stocking Strategy</b></br>
#
# 📊 Data-Informed Recommendations:
#
#
#
# <ol>
#   <li> Increase inventory of top-selling products (whole milk, bread, yogurt).
#   <li> Bundle offers on strongly associated pairs.
#   <li> Time stocking to match weekly sales trends (e.g. weekends see spikes).<br>
# </ol>
# </summary>
# <details>
#
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown">  Smart Inventory Targets</font></font>
#   </a>
#  <br>
# <big>
# <br>
#
# <table>
#   <tr><th>Item </th><th>Base Stock </th><th> Peak Week Adjustment</th></tr>
#   <tr><td>Whole Milk </td><td>200 units </td><td> +50 on Week 50–52</td></tr>
#   <tr><td>Bread </td><td>150 units </td><td> +30 on weekends</td></tr>
# </table>
#
#
#
# </details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown"> Future Work</font></font>
#   </a>
#  <br>
# <big>
# <br>
#
#
# <ol>
#   <li> 🌍 Incorporating external data (weather, holidays)
#   <li> ⏱️ Integrating real-time demand forecasting using LSTM or Prophet
#   <li> 🤖 Automating dynamic restocking alerts
#   <li> 📍 Store-specific modeling for location-tailored strategies
# </ol>
# </summary>
# </details>

# %% [markdown]
# <details>
# <summary>
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#     <font size="5em"><font color="brown"> Summary </font></font>
#   </a>
#
# <br>
#
# <big>
# <b>Key Outcomes</b>
# <ol>
# <li> Strong co-purchase patterns identified (mxltend's Apriori)
# <li> Reliable forecasts for weekly item demand
# <li> Clear stocking and bundling strategies
# <ol>
#
# </summary>
#
# <details>
# <summary>
# <big>
# <b>Key Steps</b>
# <ol>
# <li> Validate model with real-world stocking performance
# <li> Deploy dashboards for daily predictions
# <li> Start pilot in 1–2 stores with top 10 products
# </ol>
#
# ---
# </summary>
#
# </details></details>
