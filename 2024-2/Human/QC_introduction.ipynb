# %% [markdown]
# Prelude, 序言
# ===
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      Painting
#  </a>
#   <br>
#
# <img src="https://drive.google.com/uc?export=view&id=1x8gIxcBuSQuzxEmnRrJV_x5r2gwlvtBt" width=400 />
#
#
# ---
#
# </summary>
#
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      Re-visit and Analyzing
#  </a>
#   <br>
#
# <img src="https://drive.google.com/uc?export=view&id=15uh2EhKdxQTp_PJDukymhmAIgSo_HXZP" width=400 />
#
#
# ---
#
# </summary>
#
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      如果 奧地利美術學院錄取希特勒 ...
#  </a>
#
#  XXX
# </summary>
#
# </details>

# %% [markdown]
# 智慧？無知 或 萬能?
# ===
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      蟻箱內的演化
#  </a>
#   <br>
#
# <img src="https://drive.google.com/uc?export=view&id=1jW552d9xugIl3cowDAYiWqO4EkoTs1O7" width=400 />
#
#
# ---
#
# </summary>
#
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      蟻中豪傑
#  </a>
#   <br>
#
# <img src="https://drive.google.com/uc?export=view&id=1TICfB9bvSBZBqE8t5zLG4ijnm8hC3PTL" width=400 />
#
#
# ---
#
# </summary>
#
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      自然界的 智慧 ...
#  </a>
#
#  XXX
# </summary>
#
# </details>

# %% [markdown]
# 過程，觀察 ➠ 模型 ➠ 解釋 (合理?)
# ===
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      人口
#  </a>
#   <br>
#
# <img src="https://drive.google.com/uc?export=view&id=18LJ9E0WBZruxeSwb-rQSGShuZT6DBSyX" width=400 />
#
#
# ---
#
# </summary>
#
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      數學，簡單、直接
#  </a>
#   <br>
# $$
#   人口 繁殖率 = \gamma  人口數量
# $$
# 指數成長! 人口爆炸?
#
# ---
#
# </summary>
#
# <details>
#
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      修正，S- Logister 模型
#  </a>
#   <br>
# $$
#   人口 繁殖率 = \gamma  人口數量(資源總量 - 人口數量)
# $$
#
# ---
#
#
# </summary>
#
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      社會科學
#  </a>
#   <br>
#
#   1. 經濟問題, 孩子? 房子?
#     - 日本 Nagi, 1.4 (2019)  ➠ 2.95 (2020) ➠ 2.68 (2021), 平均 1.4, [News](https://www.theguardian.com/world/2023/may/29/baby-boomtown-does-nagi-hold-the-secret-to-repopulating-japan)
#   2. 宗教, 巴西 (1.4)
#   3. 生物學, 環境惡化
#
#     <Big>不是一個簡單的等式 </Big>
#
# XXX
#
# ---
#
# </summary>
#
#
# </details>

# %% [markdown]
# 量子運算 狂潮
# ===
#
# <Big>
#
# ```
# ⬇︎⬅︎
# 古典力學 (數個世紀 ) ➠ 發現電子 ( 1897)  ➠ 量子力學
# ```
#
# 差異性
# ---
# ● 量子疊加 <br>
# <p>
# <img src="https://drive.google.com/uc?export=view&id=16MrppdNix2M0qLWpjP-QkwYGI2Lf6Ul7" width=600 />
#
#
# ● 量子糾纏<br>
#
#    - 古典力學: 物體只能與「真實」的事物「運作」<br>
#    - 量子力學: 則由其所有機率狀態組合 ➠ 了解一個機率定位， 就了解另一個亞的機率定位 (量子糾纏)
#
#
# <Big><Big><B> 計算 QC:</B></Big></Big> <Big> 快 <Big><font color="brown"> 快 <Big> <font color="red">更快 </font></Big></Big></Big>
#
#
# 美國銀行主題研究主管 Haim Israel
#
# ```
# 不久的將來，進行的計算量 (量子計算機 上) 將超過可見宇宙中的原子。
# ```
#
# 2024/12, Google 推出了最新的量子處理器 Willow:
#
# ```
# 五分鐘 計算能力 > 十億年
# ```
#
# 應用
# ---
# 1. 疾病治療，識別、定位、插入、切割或修復基因的基礎運算能力的穩健性
# 2. 產品測試，(電動車的電池)，計算速度快，模擬快

# %% [markdown]
# 近代科學
# ===
#
# <Big>
# 俄羅斯烏克蘭大戰，一場大混戰.<Br>
# 俄羅斯 戰機 的殘骸，發現了 Intel, 美光， Marvel 等美國公司的晶片. <br>
#
# 台灣神山
# ---
# 台積電 先進製程，獨霸一方
#
# 模擬圖如下：
# <p>
#
# <video width="600" height="480" controls>
#   <source src="https://drive.google.com/uc?export=view&id=18FQ1f5OMesz9gWkl9GY6u7uOmD72-E_O" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# <a href="https://drive.google.com/file/d/18FQ1f5OMesz9gWkl9GY6u7uOmD72-E_O/view?usp=drive_link">Quantum Tunnel</a>

# %% [markdown]
# <details>
# <summary>
# <Big>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      計算機， 演化紀錄
#  </a>
#   <br>
#   <p>
#   1984, (aztech C)
#
# <p>
# <img src="https://drive.google.com/uc?export=view&id=10xORfV-v1gD2sEBDHNc-Wwoyu4-1Zzz9" width=480 />
#
#  <p>
#   2024. IBM 「蒼鷺」
#
# <img src="https://drive.google.com/uc?export=view&id=188b7ejbhz8BfrBDzsBKalsMiN4tBun6x" width=480 />
# ---
# </summary>
# <details>
# <summary>
# <Big>
# 軟體，IBM (qiskit, Python)
#
# 應用：藥物研發、化肥生產、電池性能 等等
#
# ---
#
# </summary>
# <details>
# <summary>
# <Big>
# 耳語
#
# Meta 停止人工智慧模型之間的交流計劃
#
# xxx
#
# </summary>
#
# </details></details>

# %% [markdown]
#  量子力學 vs 量子 計算
# ===
#
# <img src="https://drive.google.com/uc?export=view&id=1jtDaSzUh0yDTdrUPGX-VPvou2nTYc3oA" width=480 />

# %% [markdown]
#  量子 計算
# ===
# 古藤 老樹 昏鴉
# ---
# <img src="https://drive.google.com/uc?export=view&id=1u3vjz5skzXh3G3izlRRm_yGK1YuB6iDC" width=480 />
# <p>
#
# <del>站在巨人的肩膀上</del>
# ---
#
# <img src="https://drive.google.com/uc?export=view&id=1zF4vkBFAZsIU33GXYWwVML3GzmcpeE5f" width=480 />

# %% [markdown]
# <details>
# <summary>
# <Big>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      量子世界, 奇妙法則
#  </a>
#   <br>
#   <p>
#
#   機率 <Big>➠</Big> 存在性
#   <p>
#
#
# 傳統電腦 <Big>⇔</Big> 量子電腦
# <p>
#
# <img src="https://drive.google.com/uc?export=view&id=1d6HG0xb7B3-ryHDaH9eXibsZdLTEgly_" width=400 />
#
# ---
#
# </summary>
# <details>
# <summary>
# 為什麼量子計算優於傳統？
#
# 比較 旅遊歐洲 19 個國家 最短路線
#
# 傳統計算， $19!$<br>
# 量子計算， $\sqrt{19!}$<br>
#
# ---
#
# </summary>
# <details>
# <summary>
#
# <Big>
# 4-bits 量子計算 (IBM qiskit)
#
# <pre>
#      ┌─────────────────┐┌─┐
# q_0: ┤ Initialize(1,0) ├┤M├─────────
#      ├─────────────────┤└╥┘┌─┐
# q_1: ┤ Initialize(1,0) ├─╫─┤M├──────
#      ├─────────────────┤ ║ └╥┘┌─┐
# q_2: ┤ Initialize(0,1) ├─╫──╫─┤M├───
#      ├─────────────────┤ ║  ║ └╥┘┌─┐
# q_3: ┤ Initialize(0,1) ├─╫──╫──╫─┤M├
#      └─────────────────┘ ║  ║  ║ └╥┘
# c: 4/════════════════════╩══╩══╩══╩═
#                          0  1  2  3
# </pre>
#
# <img src="https://drive.google.com/uc?export=view&id=1tquF1F7T7q-qzYWKfYmFGU3cHdS0tt-d" width=480 />
#
# ---
#
# </summary>
# <details>
# <summary>
# <Big>
# 另外的
# <p>
# <small>
# <pre>
#       ┌─────────────────────────────┐ ┌─┐
# q_0: ─┤ Initialize(0.70711,0.70711) ├─┤M├─────────
#       ├─────────────────────────────┴┐└╥┘┌─┐
# q_1: ─┤ Initialize(0.70711,-0.70711) ├─╫─┤M├──────
#       ├──────────────────────────────┤ ║ └╥┘┌─┐
# q_2: ─┤ Initialize(0.70711,0.70711j) ├─╫──╫─┤M├───
#      ┌┴──────────────────────────────┤ ║  ║ └╥┘┌─┐
# q_3: ┤ Initialize(0.70711,-0.70711j) ├─╫──╫──╫─┤M├
#      └───────────────────────────────┘ ║  ║  ║ └╥┘
# c: 4/══════════════════════════════════╩══╩══╩══╩═
#                                        0  1  2  3
# </pre>
# </small>
#
# <img src="https://drive.google.com/uc?export=view&id=1KP5ylstG1dDduSmko9vzA_55AuR4MsV4" width=480 />
#
#
# ---
#
# </summary>
# <details>
# <summary>
# <Big>
# 備註:
#
# <Big>IBM's 平台已經不再公開，qiskit 穩定版釋放 (1.2.4, 2024/11/22) </Big>
#
# XXX
# </details></details></details></details>

# %% [markdown]
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      薛丁格的貓
#  </a>
#   <br>
#
# <img src="https://drive.google.com/uc?export=view&id=1E0_QyldRe003SkFrfsyaGtAlpVK7lGG6" width=400 />
#
#   <p>
# 箱子
# <ol>
#     <li> 貓
#     <li> 探測器
#     <li> 毒藥
# </ol>
#
# ---
#
# </summary>
# <details>
# <summary>
# <Big>
# 規則
# <ol>
#   <li> 原子衰變 <big>➠</big> 探測器會啟動
#   <li> 探測器啟動 <big>➠</big> 毒藥瓶打開 <big>➠</big> 貓咪死亡
# </ol>
#
# ---
# </summary>
# <details>
# <summary>
# <Big>
# 箱子打開之前 <p>
#
# <big>➠</big> 貓咪  <font color="blue">活的</font> 貓咪 (<big>√</big>) ， <font color="red">死的</font>貓咪 <font color="blue">(<big>√</big>)
#
# ---
# </summary>
# <details>
# <summary>
# 打開箱子，觀察一瞬間<p>
#
# 貓咪才會「選擇」成為 <font color="red">活的</font> (<big>√</big>)
# <font color="red">死的</font>(<big>√</big>)
#
# ---
# </summary>
# <details>
# <summary>
# 量子世界：<p>
# 在被觀察之前，所有可能性 (<font color="brown">狀態</font>) 同時存在！
#
# xxx
# </summary>
# </details></details></details></details>

# %% [markdown]
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      鬼魅粒子，量子糾纏
#  </a>
#   <br>
# 雙胞胎，愛麗絲 alice 跟 鮑伯 Bob：感應相同
#
# ---
#
# </summary>
# <details>
# <summary>
#
# <Big>
# 量子糾纏實驗：
# <p>
# <Big>
# 📡 實驗細節<br>
#
# - 地點：中國 ，奧地利
# - 距離：約1200公里
# - 量子通訊衛星「墨子號」
#
# ---
#
# </summary>
# <details>
# <summary>
# <p>
# <Big>
# 🔬 具體過程：
#
# - 製造一對量子糾纏的光子
# - 發送這對光子到 中國 和 奧地利
# - 這對光子保持著神祕的「同步」
#
# ---
#
# </summary>
# <details>
# <summary>
# <Big>
# 結論<br>
#
# - 一個光子的量子態瞬間影響另一個<br>
# - 突破光速限制<br>
# - 完全即時通訊<br>
#
# ---
#
# </summary>
# <details>
# <summary>
# <Big>
# 應用潛力：<br>
#
# <Big>
# - 未來的超安全通訊系統
# - 量子加密技術
# - 跨洲即時數據傳輸
#
# xxx
#
# </summary>
# </details></details></details></details></details>

# %% [markdown]
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      量子計算：革命性 發展
#  </a>
#   <br>
#   醫療，環境，金融
#
# ---
#
# </summary>
# <details>
# <summary>
# 醫療：精準藥物設計
# <p>
# 進展<p>
# - 模擬蛋白質 folding, 降低開發成本<br>
# - 預測藥物分子結構, 縮短新藥研發週期<br>
# - 個人化醫療方案, 特定基因的客製化治療<br><br>
#
# ---
#
#
# <b>Reference</b><br>
# 1. Nature: https://www.nature.com/articles/d41586-019-02935-4<br>
# 2. MIT Technology Review: https://www.technologyreview.com/2020/10/16/1010222/quantum-computing-drug-discovery/<br>
#
#
# ---
#
# </summary>
#
# <details>
# <summary>
# 環境：氣候模擬
# <p>
# <b>關鍵能力</b><br>
#
# - 複雜氣候系統多維度模擬<br>
# - 即時碳排放預測<br>
# - 極端氣候事件預警<br>
#
# <b>潛在影響</b><br>
# - 精確氣候變遷模型<br>
# - 減緩全球暖化策略<br>
# - 調整農業和城市規劃 <br>
#
# <b>Reference</b><br>
# - NASA: https://science.nasa.gov/climate-change/<br>
# - Nature Climate Change: https://www.nature.com/nclimate/<br>
#
# ---
#
# </summary>
#
# <details>
# <summary>
# 金融：風險評估<p>
# 1. 即時複雜投資組合分析, 降低金融風險<br>
# 2. 超高頻交易風險評估, 提高投資準確性<br>
# 3. 金融衍生品建模, 即時市場預測<br>
#
# <b>Reference</b><br>
# 1. World Economic Forum: https://www.weforum.org/agenda/2021/03/quantum-computing-finance-explained/<br>
# 2. Bloomberg: https://www.bloomberg.com/professional/blog/quantum-computing-financial-services/<br>
#
# xxx
#
# </details></details></details></details></details>

# %% [markdown]
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      世界改變
#  </a>
#   <br>
# 谷歌量子霸權, 2019
# <ol>
#     <li> 53個量子比特處理器「Sycamore」
#     <li> 計算能力 = 超級電腦 1 萬年的計算
# </ol>
#
# ---
#
# </summary>
# <details>
# <summary>
# IBM 量子雲端平台
# <ol>
#     <li> 降低量子計算進入門檻
#     <li> 促進跨領域創新
# </ol>
#
# ---
#
# </summary>
# <details>
#  <summary>
# 中國墨子號量子衛星, 2017
#
# 量子雷達<br>
#
# <img src="https://drive.google.com/uc?export=view&id=1hMJXKhNiJ69gLbEHUfD_DcTkUzhuwyym" width=400 />
#
# <ol>
#     <li> 創造 > 1000 公里量子糾纏紀錄
#     <li> 證明量子通訊安全可行性
# </ol>
#
# <b>Refencrce</b><br>
# 1. Barzanjeh, S., Guha, S., Weedbrook, C., Vitali, D., Shapiro, J. H., & Pirandola, S. (2015). Microwave quantum illumination. Physical Review Letters, 114(8).<br>
# 2. Krelina, M. (2021). Quantum technology for military applications. EPJ Quantum Technology, 8(1).<br>
#
#
# ---
#
# </summary>
# <details>
# <summary>
# 阿里巴巴量子計算實驗室, 商業應用
# <ol>
#     <li> 金融風險模擬
#     <li> 物流優化
#     <li> 人工智能深度學習
# </ol>
#
# ---
#
# </summary>
# <details>
# <summary>
# 劍橋大學量子生物學突破
# <ol>
#     <li> 首次在生物系統中證明量子效應
#     <li> 解釋光合作用的能量傳遞機制
#     <li> 開闢量子生物技術新領域
# </ol>
#
# ---
#
# </summary>
#
# <details>
# <summary>
# 結論<p>
#
# - 量子計算正從實驗室走向現實<br>
# - 跨國、跨領域的協作至關重要<br>
# - 每一次突破都在重新定義技術可能性<br>
#
# <p>
#
# <b>Reference</b><br>
# Nature量子科技頻道: https://www.nature.com/subjects/quantum-technologies
#
# </summary>
# </details></details></details></details></details>

# %% [markdown]
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      量子未來
#  </a>
#   <br>
#
# - 醫療革命 <br>
# - 環境再生 <br>
# - 資訊安全 <br>
# - 經濟範式 <br>
#
# ---
#
# </summary>
# <details>
# <summary>
# 未來想像<p>
#
# - 個人量子助理<br>
# - 免疫系統<br>
# - 星系通訊<br>
#
#
# XXX
# </summary>
# </details></details></details></details>

# %% [markdown]
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      補充
#  </a>
#
# <a href="https://kelispinor.medium.com/%E9%87%8F%E5%AD%90%E9%9B%BB%E8%85%A6%E6%A5%B5%E7%B0%A1%E4%BB%8B-short-introduction-to-quantum-computer-a7b159861786">量子電腦：從原理、實作到應用</a>
#
#
# ---
#
# </summary>
# <details>
# <summary>
# <Big>
# 一，量子電腦的特色
#
# <p>
# - 量子疊加 (quantum superposition)：狀態的組合<br>
# - 量子糾纏 (quantum entanglement)：資訊也藏在關聯性中
#
# 量子糾纏 可以測量，<font color="brown">量子疊加 否定的</font>
# ---
# </summary>
# <details>
# <summary>
# 二，量子演算法
#
# 快但少<br>
# - 質因數分解<br>
# - 未排序資料庫搜尋<br>
# - 量子傅立葉轉換<br>
# ---
# </summary>
# <details>
# <summary>
# 三， 實際應用
#
# - D-Wave, Volkswagen, 北京計程車派出的時間
# - IonQ, 2024/10, 美國國防部
# - Rigetti, 提供量子雲端平台
#
# ---
# </summary>
# <details>
# <summary>
#
# 台灣 小道消息
# ---
#
# - 台積電與 3nm 晶片開發 同時 發展 (<font color="brown">?</font>)
# - 國科會 (科技部) 計畫每年經費 7000 萬元 (2018)，
#
# XXX
# </summary>
# </details></details></details></details>

# %% [markdown]
# 量子骰子
# ===
# [嘗試](http://120.126.22.75:8501) <br>
#
#
# <Big>
# <b>http://120.126.22.75:8501</b>
#
# <p>
# 每個人都是一樣的連接點 (量子狀態)， 結果 (測量) 不盡然相同!

# %%
https://twitter.com/i/status/1570519267631861761

# %% [markdown]
# 迷幻
# ===
# 注意看中心約20秒， 然後欣賞 Von Gogh 的 星月 starry night
#
# <a href="https://twitter.com/i/status/1570519267631861761
# ">X</a>

# %%
from IPython.display import Image

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1u_NDT3LdHQBZiVP6rFXJZBV9lJN3l2m5" width=600 />

# %% [markdown]
# 生活 小道消息
# ===
#
# 1. 拿破崙稱讚 Laplace 的天體力學:
#
# > 經常在牛頓的書中找到上帝的名字,但在你的書中卻沒有找到。
# Laplace:
# > 我不需要這個假設。
#
# 英國 艾倫·圖靈（Alan Turing):
# > 科學是一個微分方程。宗教是邊界條件。

# %% [markdown]
# <Big>
# 2. 巴哈家族 著名的音樂世家，伯努利 (Bernoulli) 家族 則在 數學界 著名.
#
# Daniel Bernoulli 向牛頓自我介紹:
# > 很高興認識您,我是Daniel Bernoulli。
#
# 牛頓
# > 是艾薩克·牛頓
#
#
# <img src="https://drive.google.com/uc?export=view&id=108rz1aQoID29xeRQxEuKJxcJfcPFe6SN" width=600 />
#
# 利用白努力定律，Daniel Bernoulli 發明血壓器. (取代前者的侵入式設計，義大利人 S.R. Rocci 發明近代的血壓器)

# %% [markdown]
# 3. O 型環，造成太空場爆炸，1986, Feynman 向 NASA 解釋<br>
# <img src="https://drive.google.com/uc?export=view&id=145HByOVmkrQ0_qzC-9_H0xXRZGOsZOMb" width=600 />

# %% [markdown]
# 4. 黃金比無所不在，$\varphi = 1.6180339887...$,  Aston Martin DB9:
#
# <img src="https://drive.google.com/uc?export=view&id=161MlQ7sP4K6C4FcWCii1Js9U_dpBwKBY" width=600 />

# %% [markdown]
# 5. 理論 實驗
# ---
# <Big>
# <img src="https://drive.google.com/uc?export=view&id=1k8Ipsp2oicfsgdRHl9TpIJV77xRskGwj" width=480 />
#
#
# Pyotr Kapitsa, 1978 諾貝爾獎得主， 說兩位理論物理學家討論:
#  > 攪拌茶 時，什麼讓茶變得甜。是加糖還是攪拌？
#
# 決定去問另一個同事 Lev Landau，隔天，他回答:
# > 我明白了，如果不加糖，茶就不需要攪拌了。
#
#
# 大團結
# ---
# "<font color="brown">```釋放 Landau， 否則退出物理界```</font>"，Pyotr Kapitsa 威脅； V.I Arnold 在法國 聲援. 後者什麼數學獎項都得過，唯獨數學大獎 Field Medal 沒有，因為 俄羅斯數學學會堅持反對.
#
# <img src="https://drive.google.com/uc?export=view&id=1h4wndQzHX9Zbc9mPLSOr7n3xU-hKVIZa" width=480 />
#
#
# 金庸全套<br>
#
# <img src="https://drive.google.com/uc?export=view&id=1aPOKcRdLt8tEbjbB07DVjngjVZkeCwgq" width=480 />

# %% [markdown]
# 月亮照片
# ---
#
# 一張一張比對， 16歲青年 的傑作：<br>
# <img src="https://drive.google.com/uc?export=view&id=1jiO3p9SLOoEw1JBuuop6NMXEuXEUtLT3" width=480 />

# %% [markdown]
# <details>
# <summary>
# <font size="5em">
#  <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>
#      鳥類的飛行導向雷達<br>
#  </a>
#
# <font size="4em">
# 遼闊天空中，侯鳥如何遷移?
#
# ---
# </summary>
#
# <details>
# <summary>
#
# <Big>
# <ol>
# <li> 空間迷航，九孔在空軍飛行班時，因為空間迷航，而將飛機 降落在高速公路.
# <li> 身為恐龍的後代，天空中的鳥類，如何循著軌道前進？ "量子糾纏"
# </ol>
#
# ---
#
# </summary>
#
# <details>
# <summary>
#
# <Big>
# <b>
# "Cryptochromes", 視網膜中的蛋白質:
# </b>
#
# <img src="https://drive.google.com/uc?export=view&id=1W4lETYSG744zwVUmL8iHv2lw2_FHon9i" width=600 />
#
# <pre>
#
#                 藍光               地磁.
#   Cryptochromes  ➠  一對糾纏的 電子   ➠  化學反應
#                                          ⬇︎ 鳥類的方向角度
#                                        視覺影像
# </pre>
#
# <img src="https://drive.google.com/uc?export=view&id=1hDUb5daE73Q-Qj2SBBupKodLoUJnjuL6" width=600 />
#
# ---
#
# </summary>
# <details>
# <summary>
#
# 為什麼人沒有? 是不是所有鳥類都有?
#
#
# <a href="https://www.quora.com/How-does-quantum-entanglement-in-bird-brains-enable-them-to-detect-magnetic-fields/answer/Nitin-Bidani?ch=15&oid=1477743832410838&share=4f0a6720&srid=hUhSf&target_type=answer">Reference</a>
#
# XXX
# </summary>
#
# </details></details></details>

# %% [markdown]
# 問題 1: 真或假：量子計算是一種古典計算，它使用量子力學現象對數據進行操作。
#
# 答案：錯誤（量子計算是一種獨立的計算，它使用量子力學現象對數據進行操作，而不是古典計算。）
#
# 問題 2: 真或假：量子電腦可以對某些問題進行的運算速度遠快於古典電腦。
#
# 答案：正確
#
# 問題 3: 真或假：量子計算仍然在其初期發展，尚未在工業中廣泛應用。
#
# 答案：正確
#
# 問題 4: 真或假：量子電腦需要大量的 qubit 進行複雜的計算。
#
# 答案：正確
#
# 問題 5: 真或假：量子計算只對複雜數學問題有用，並沒有實際應用。
#
# 答案：錯誤（量子計算有許多實際應用，包括加密、優化和機器學習等。）
#
#
# 問題 4: 真或假：傅立葉級數 除了可以將訊號變為圖形來觀察，也可以用於預測未來的信號變化，如氣象報告。
#
# 答案：正確
#
# 問題 5: 真或假：傅立葉級數只是一種數學工具： 可以將函數分解為無窮多個三角函數的組合，但是沒有實際應用。
#
# 答案：錯誤（傅立葉級數有很多實際應用，例如音頻處理、圖像處理和信號處理等。）
#
# 問題：蠟燭燃燒時，靠近 燈蕊 的地方， 空氣的溫度較高，煙迅速上升，形成筆直的形狀，很快的，周圍空氣的溫度降低，煙上升速度變慢，形成渦流.
#
# 答案：正確
